# %%
import folium
import pandas as pd
df = pd.read_csv('./df_final.csv')

# %%
from folium import plugins
# [34.632093,-120.610829] 'VAFB SLC 4E'
m_VAFB = folium.Map(
    [34.632093,-120.610829],
    zoom_start= 16,control_scale=True
)

folium.Marker(
    location = [34.632093,-120.610829],
    popup='VAFB SLC 4E',
    icon=folium.Icon(color='pink')
).add_to(m_VAFB)

folium.Circle(
    radius=50,
    location = [34.631,-120.610829],
    popup='VAFB SLC 4E success',
    color = "#00CC66",
    fill = True
).add_to(m_VAFB)

folium.Circle(
    radius=50,
    location = [34.633,-120.610829],
    popup='VAFB SLC 4E False',
    color = "#FF0000",
    fill = True
).add_to(m_VAFB)

marker1 = plugins.MarkerCluster().add_to(m_VAFB)
marker2 = plugins.MarkerCluster().add_to(m_VAFB)

for j in range(len(df[df['launchpad_name']=='VAFB SLC 4E'])):
    if df[df['launchpad_name']=='VAFB SLC 4E'].iloc[j].success:
        folium.Marker([34.631,-120.610829]).add_to(marker1)
    else:
        folium.Marker([34.633,-120.610829]).add_to(marker2)
m_VAFB
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f86e9caa850545d49b20db0e2649a1a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f86e9caa850545d49b20db0e2649a1a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f86e9caa850545d49b20db0e2649a1a3 = L.map(
#                 &quot;map_f86e9caa850545d49b20db0e2649a1a3&quot;,
#                 {
#                     center: [34.632093, -120.610829],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f86e9caa850545d49b20db0e2649a1a3);
#
#
#
#
#
#             var tile_layer_2956323a7f3fbe60f899388d2c691d69 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f86e9caa850545d49b20db0e2649a1a3);
#
#
#             var marker_036c33366929f53636a1386155e0d2d8 = L.marker(
#                 [34.632093, -120.610829],
#                 {}
#             ).addTo(map_f86e9caa850545d49b20db0e2649a1a3);
#
#
#             var icon_de79be0bf903cc0ec7cf790bd3fcac5e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_036c33366929f53636a1386155e0d2d8.setIcon(icon_de79be0bf903cc0ec7cf790bd3fcac5e);
#
#
#         var popup_247240a16fbbfa2ca9eaa0c041f4583c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_569906359a6b0b95149a63f38b81a0c2 = $(`&lt;div id=&quot;html_569906359a6b0b95149a63f38b81a0c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC 4E&lt;/div&gt;`)[0];
#             popup_247240a16fbbfa2ca9eaa0c041f4583c.setContent(html_569906359a6b0b95149a63f38b81a0c2);
#
#
#         marker_036c33366929f53636a1386155e0d2d8.bindPopup(popup_247240a16fbbfa2ca9eaa0c041f4583c)
#         ;
#
#
#
#
#             var circle_fd1815a19d9ff24d3527f17292937b4a = L.circle(
#                 [34.631, -120.610829],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00CC66&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00CC66&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f86e9caa850545d49b20db0e2649a1a3);
#
#
#         var popup_c6d67188452bbfe2e2f35e4173a01fd2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_086154192e2950712a942d5e7c6e31cb = $(`&lt;div id=&quot;html_086154192e2950712a942d5e7c6e31cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC 4E success&lt;/div&gt;`)[0];
#             popup_c6d67188452bbfe2e2f35e4173a01fd2.setContent(html_086154192e2950712a942d5e7c6e31cb);
#
#
#         circle_fd1815a19d9ff24d3527f17292937b4a.bindPopup(popup_c6d67188452bbfe2e2f35e4173a01fd2)
#         ;
#
#
#
#
#             var circle_12f1f7fb518cf6838eaffc0375f05141 = L.circle(
#                 [34.633, -120.610829],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f86e9caa850545d49b20db0e2649a1a3);
#
#
#         var popup_228f30852de06fdd7a13946693882223 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cb98970f0704cd6e2b03bfc030c041cb = $(`&lt;div id=&quot;html_cb98970f0704cd6e2b03bfc030c041cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC 4E False&lt;/div&gt;`)[0];
#             popup_228f30852de06fdd7a13946693882223.setContent(html_cb98970f0704cd6e2b03bfc030c041cb);
#
#
#         circle_12f1f7fb518cf6838eaffc0375f05141.bindPopup(popup_228f30852de06fdd7a13946693882223)
#         ;
#
#
#
#
#             var marker_cluster_c7f733505f857082f81a701e2bd1c

# %%
from folium import plugins
# [28.561857,-80.577366] 'CCSFS SLC 40'
m_CCSFS = folium.Map(
    [28.561857,-80.577366],
    zoom_start= 16,control_scale=True
)

folium.Marker(
    location = [28.5618571,-80.577366],
    popup='CCSFS SLC 40',
    icon=folium.Icon(color='blue')
).add_to(m_CCSFS)

folium.Circle(
    radius=50,
    location = [28.561,-80.577],
    popup='CCSFS SLC 40 success',
    color = "#00CC66",
    fill = True
).add_to(m_CCSFS)

folium.Circle(
    radius=50,
    location = [28.561,-80.578],
    popup='CCSFS SLC 40 False',
    color = "#FF0000",
    fill = True
).add_to(m_CCSFS)

marker1c = plugins.MarkerCluster().add_to(m_CCSFS)
marker2c = plugins.MarkerCluster().add_to(m_CCSFS)

for j in range(len(df[df['launchpad_name']=='CCSFS SLC 40'])):
    if df[df['launchpad_name']=='CCSFS SLC 40'].iloc[j].success:
        folium.Marker([28.561,-80.577]).add_to(marker1c)
    else:
        folium.Marker([28.561,-80.578]).add_to(marker2c)
m_CCSFS
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a7eeeb8bb3a3fd5e1376dc5efba4753 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a7eeeb8bb3a3fd5e1376dc5efba4753&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6a7eeeb8bb3a3fd5e1376dc5efba4753 = L.map(
#                 &quot;map_6a7eeeb8bb3a3fd5e1376dc5efba4753&quot;,
#                 {
#                     center: [28.561857, -80.577366],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_6a7eeeb8bb3a3fd5e1376dc5efba4753);
#
#
#
#
#
#             var tile_layer_4c0cd0564193bde94a8128e5e31c64e4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6a7eeeb8bb3a3fd5e1376dc5efba4753);
#
#
#             var marker_9f60ac2d5a49ca93a58ad13e643873f9 = L.marker(
#                 [28.5618571, -80.577366],
#                 {}
#             ).addTo(map_6a7eeeb8bb3a3fd5e1376dc5efba4753);
#
#
#             var icon_d7fb17b2f3f867e89616d0d41d252ae0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9f60ac2d5a49ca93a58ad13e643873f9.setIcon(icon_d7fb17b2f3f867e89616d0d41d252ae0);
#
#
#         var popup_881006c7628d36bf3f70fea553ec5983 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d08f40d37b3afce4c215afb3e6091d3e = $(`&lt;div id=&quot;html_d08f40d37b3afce4c215afb3e6091d3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCSFS SLC 40&lt;/div&gt;`)[0];
#             popup_881006c7628d36bf3f70fea553ec5983.setContent(html_d08f40d37b3afce4c215afb3e6091d3e);
#
#
#         marker_9f60ac2d5a49ca93a58ad13e643873f9.bindPopup(popup_881006c7628d36bf3f70fea553ec5983)
#         ;
#
#
#
#
#             var circle_de2d91235cca2e1b7155ff6c072f378f = L.circle(
#                 [28.561, -80.577],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00CC66&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00CC66&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6a7eeeb8bb3a3fd5e1376dc5efba4753);
#
#
#         var popup_7a4e673ea7ff59a444a766dea597969e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d9a4374f479e692cbbcbdc345e37cf28 = $(`&lt;div id=&quot;html_d9a4374f479e692cbbcbdc345e37cf28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCSFS SLC 40 success&lt;/div&gt;`)[0];
#             popup_7a4e673ea7ff59a444a766dea597969e.setContent(html_d9a4374f479e692cbbcbdc345e37cf28);
#
#
#         circle_de2d91235cca2e1b7155ff6c072f378f.bindPopup(popup_7a4e673ea7ff59a444a766dea597969e)
#         ;
#
#
#
#
#             var circle_5b7c53f50c3af9a062fd06b5518b89cc = L.circle(
#                 [28.561, -80.578],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6a7eeeb8bb3a3fd5e1376dc5efba4753);
#
#
#         var popup_6070f4756e929c3f2bb501b95086bb7b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7fd16be368ad57ce35173b03867e06df = $(`&lt;div id=&quot;html_7fd16be368ad57ce35173b03867e06df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCSFS SLC 40 False&lt;/div&gt;`)[0];
#             popup_6070f4756e929c3f2bb501b95086bb7b.setContent(html_7fd16be368ad57ce35173b03867e06df);
#
#
#         circle_5b7c53f50c3af9a062fd06b5518b89cc.bindPopup(popup_6070f4756e929c3f2bb501b95086bb7b)
#         ;
#
#
#
#
#             var marker_cluster_99fd28a2fb1826325997480fea39e184 =

# %%
from folium import plugins
m_KSC = folium.Map(
    [28.608058,-80.603956],
    zoom_start= 16,control_scale=True
)

folium.Marker(
    location = [28.608058,-80.603956],
    popup='KSC LC 39A',
    icon=folium.Icon(color='red')
).add_to(m_KSC)

folium.Circle(
    radius=50,
    location = [28.607,-80.603956],
    popup='CCSFS SLC 40 success',
    color = "#00CC66",
    fill = True
).add_to(m_KSC)

folium.Circle(
    radius=50,
    location = [28.607,-80.605],
    popup='CCSFS SLC 40 False',
    color = "#FF0000",
    fill = True
).add_to(m_KSC)

marker1k = plugins.MarkerCluster().add_to(m_KSC)
marker2k = plugins.MarkerCluster().add_to(m_KSC)

for j in range(len(df[df['launchpad_name']=='CCSFS SLC 40'])):
    if df[df['launchpad_name']=='CCSFS SLC 40'].iloc[j].success:
        folium.Marker([28.607,-80.603956]).add_to(marker1k)
    else:
        folium.Marker([28.607,-80.605]).add_to(marker2k)
m_KSC
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0490e60646ee3e69dc07e7c12bc73c6f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0490e60646ee3e69dc07e7c12bc73c6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0490e60646ee3e69dc07e7c12bc73c6f = L.map(
#                 &quot;map_0490e60646ee3e69dc07e7c12bc73c6f&quot;,
#                 {
#                     center: [28.608058, -80.603956],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0490e60646ee3e69dc07e7c12bc73c6f);
#
#
#
#
#
#             var tile_layer_bdb47107e12280137b2f9a7acb0fe3f2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0490e60646ee3e69dc07e7c12bc73c6f);
#
#
#             var marker_442317556fa1b6385121f3a8378a01ec = L.marker(
#                 [28.608058, -80.603956],
#                 {}
#             ).addTo(map_0490e60646ee3e69dc07e7c12bc73c6f);
#
#
#             var icon_a347f129d68e8880ec0d952c475c3e22 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_442317556fa1b6385121f3a8378a01ec.setIcon(icon_a347f129d68e8880ec0d952c475c3e22);
#
#
#         var popup_af5eeb146dfb5b13ad18b12c74393abf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6c007a2d3e7876231742b865a3717e24 = $(`&lt;div id=&quot;html_6c007a2d3e7876231742b865a3717e24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC 39A&lt;/div&gt;`)[0];
#             popup_af5eeb146dfb5b13ad18b12c74393abf.setContent(html_6c007a2d3e7876231742b865a3717e24);
#
#
#         marker_442317556fa1b6385121f3a8378a01ec.bindPopup(popup_af5eeb146dfb5b13ad18b12c74393abf)
#         ;
#
#
#
#
#             var circle_9b566b264b12c4d9b09459228b8600b4 = L.circle(
#                 [28.607, -80.603956],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00CC66&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00CC66&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0490e60646ee3e69dc07e7c12bc73c6f);
#
#
#         var popup_57a63c79e7663eba0afc173504d1726a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_bd981d2ffe0364a9c98157bfef81f487 = $(`&lt;div id=&quot;html_bd981d2ffe0364a9c98157bfef81f487&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCSFS SLC 40 success&lt;/div&gt;`)[0];
#             popup_57a63c79e7663eba0afc173504d1726a.setContent(html_bd981d2ffe0364a9c98157bfef81f487);
#
#
#         circle_9b566b264b12c4d9b09459228b8600b4.bindPopup(popup_57a63c79e7663eba0afc173504d1726a)
#         ;
#
#
#
#
#             var circle_7ea6951d2764512500bd4849682d52ce = L.circle(
#                 [28.607, -80.605],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0490e60646ee3e69dc07e7c12bc73c6f);
#
#
#         var popup_7f2e8bdaffc1ddd543af927bed0282e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_bffc78ab199d895959c371553c8aa1dc = $(`&lt;div id=&quot;html_bffc78ab199d895959c371553c8aa1dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCSFS SLC 40 False&lt;/div&gt;`)[0];
#             popup_7f2e8bdaffc1ddd543af927bed0282e8.setContent(html_bffc78ab199d895959c371553c8aa1dc);
#
#
#         circle_7ea6951d2764512500bd4849682d52ce.bindPopup(popup_7f2e8bdaffc1ddd543af927bed0282e8)
#         ;
#
#
#
#
#             var marker_cluster_8f4808b15e259136e9c4b16215189648 = L
